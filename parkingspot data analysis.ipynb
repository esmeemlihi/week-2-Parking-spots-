# %%
import numpy as np
import pandas as pd

# %%
parking = pd.read_csv('result.csv')

# %%
parking.columns
# Out:
# Index(['WKT', 'id', 'geo_id', 'buurtcode', 'stadsdeel', 'straatnaam', 'aantal',
#        'soort', 'type', 'e_type', 'e_type_desc', 'bord'],
#       dtype='object')

# %%
columns_english = ["WKT", "ID", "GEO_ID", "NEIGBORHOOD_CODE", "URBAN_AREA", 
                   "SREET_NAME", "QUANTITY", "CATEGORY", "TYPE", "E_TYPE", "E_TYPE_DESC", "SIGN"]


parking.columns= columns_english

# %%
parking.to_csv('parking.csv')
parking
# Out:
#                                                       WKT            ID  \
# 0       POLYGON ((110677.64 492542.17,110672.28 492543...  110675492544
# 1       POLYGON ((110683.02 492541.02,110677.64 492542...  110681492543
# 2       POLYGON ((110683.44 492542.97,110690.81 492541...  110687492541
# 3       POLYGON ((111725.48 491372.13,111724.98 491369...  111723491371
# 4       POLYGON ((111725.98 491374.5,111725.48 491372....  111724491374
# ...                                                   ...           ...
# 267385  POLYGON ((131901.8 491285.23,131898.87 491280....  131899491284
# 267386  POLYGON ((131903.16 491288.42,131902.66 491286...  131901491288
# 267387  POLYGON ((131905.75 491294.64,131903.68 491290...  131903491293
# 267388  POLYGON ((131907.97 491299.74,131907.85 491299...  131905491298
# 267389  POLYGON ((131913.19 491317.17,131910.89 491309...  131909491306
#
#               GEO_ID NEIGBORHOOD_CODE    URBAN_AREA     SREET_NAME  QUANTITY  \
# 0       110675492544             B10g  westpoort_nf     Abidjanweg         1
# 1       110681492543             B10g  westpoort_nf     Abidjanweg         1
# 2       110686492541             B10g  westpoort_nf     Abidjanweg         1
# 3       111723491371             B10g  westpoort_nf       Ruigoord         1
# 4       111724491374             B10g  westpoort_nf       Ruigoord         1
# ...              ...              ...           ...            ...       ...
# 267385  131899491284             N73g      noord_nf  Uitdammerdijk         1
# 267386  131901491288             N73g      noord_nf  Uitdammerdijk         1
# 267387  131903491293             N73g      noord_nf  Uitdammerdijk         1
# 267388  131905491298             N73g      noord_nf  Uitdammerdijk         1
# 267389  131909491306             N73g      noord_nf  Uitdammerdijk         1
#
#             CATEGORY   TYPE E_TYPE E_TYPE_DESC SIGN
# 0       NIET FISCAAL  Langs    NaN         NaN  NaN
# 1       NIET FISCAAL  Langs    NaN         NaN  NaN
# 2       NIET FISCAAL  Langs    NaN         NaN  NaN
# 3       NIET FISCAAL  Haaks    NaN         NaN  NaN
# 4       NIET FISCAAL  Haaks    NaN         NaN  NaN
# ...              ...    ...    ...         ...  ...
# 267385  NIET FISCAAL  Langs    NaN         NaN  NaN
# 267386  NIET FISCAAL  Langs    NaN         NaN  NaN
# 267387  NIET FISCAAL  Langs    NaN         NaN  NaN
# 267388  NIET FISCAAL  Langs    NaN         NaN  NaN
# 267389  NIET FISCAAL  Langs    NaN         NaN  NaN
#
# [267390 rows x 12 columns]
